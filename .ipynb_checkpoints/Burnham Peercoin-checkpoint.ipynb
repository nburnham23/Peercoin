# %% [markdown]
# # Final Project: Peercoin Implementation
# ## Noah Burnham
# ## CS 3120: Secure Distributed Computation

# %%
# Imports and definitions
import numpy as np
import hashlib
from nacl.signing import SigningKey
from dataclasses import dataclass
from typing import List

# %%
DIFFICULTY = int(2**(32 * 8)/10000)

def bytes_value(v):
    return bytes(str(v), encoding='utf-8')

def hash_value(v):
    return hashlib.sha256(bytes_value(v)).hexdigest()

def get_blockchain_height(blockchain):
    height = 0
    curr = blockchain
    while curr is not None:
        height += 1
        curr = curr.prev.pointer
    return height

@dataclass
class HashPointer:
    hash: bytes
    pointer: any

# Transactions have inputs and outputs
@dataclass
class Transaction:
    inputs: list
    outputs: list

@dataclass
class Input:
    previous_tx: Transaction
    index: int
    public_key: SigningKey

# Signed inputs are signed by public keys
@dataclass
class SignedInput:
    input: Input
    signed_input: bytes

@dataclass
class Output:
    public_key_hash: hash
    value: int
    block_height: int = 0

    def __repr__(self):
        # do not use block_height because it gets mutated
        return f'Output(public_key_hash={self.public_key_hash}, value={self.value})'

# Each block has a list of transactions
@dataclass
class Block:
    transactions: list
    prev: HashPointer
    nonce: int
    pubkey_hash: hash
    block_height: int
    difficulty: int
    
    def __repr__(self):
        return f'\nBlock(\n transaction: {self.transactions},\n nonce: {self.nonce},\n prev: {self.prev}, \n block height: {self.block_height})'

# %%
def compute_coin_age(output, curr_height):
    age = curr_height - output.block_height
    return output.value * age

def get_total_stake(outputs, curr_height):
    total_stake = 0
    for o in outputs:
        total_stake += compute_coin_age(o, curr_height)
    return total_stake

def adjust_difficulty(stake):
    if stake > 0:
        scaled_difficulty = DIFFICULTY * (1 + stake/100)
        return int(scaled_difficulty)
    return DIFFICULTY

# %%
def add_block(transactions, blockchain, nonce, pubkey_hash, difficulty):
    prev_hash = hash_value(blockchain)
    prev = HashPointer(prev_hash, blockchain)
    curr_height = get_blockchain_height(blockchain)
    for tx in transactions:
        for output in tx.outputs:
            if output.block_height == 0:
                output.block_height = curr_height + 1
    new_block = Block(transactions, prev, nonce, pubkey_hash, curr_height+1, difficulty)
    return new_block, hash_value(new_block)

def mine_for_block(transactions, pubkey_hash, blockchain, stake):
    # stake is a list of outputs
    curr_height = get_blockchain_height(blockchain) + 1
    total_stake = get_total_stake(stake, curr_height)
    difficulty = adjust_difficulty(total_stake)  
    nonce = 0
    while True:
        nonce = nonce + 1
        new_block, final_hash = add_block(transactions, blockchain, nonce, pubkey_hash, difficulty)
        if int(final_hash, 16) <= difficulty:
            # reset the coin-ages once a block is mined
            for o in stake:
                o.block_height = curr_height
            print("Found a block! Nonce: ", nonce)
            return new_block, final_hash

def check_blockchain(blockchain, expected_hash):
    curr = blockchain
    if hash_value(blockchain) != expected_hash:
        raise Exception("the blockchain does not match the expected hash.")
    while curr is not None:
        # check that the difficulty is satisfied
        if int(hash_value(curr), 16) > curr.difficulty:
            raise Exception("The difficulty requirement is not satisfied.")
        # check each transaction to make sure that the sender is allowed to use that money
        for tx in curr.transactions:
            for signed_input in tx.inputs:
                inp = signed_input.input
                if inp.previous_tx == 'COINBASE':
                    continue
                try:
                    # check the signature
                    inp.public_key.verify(bytes_value(inp), signed_input.signed_input.signature)
                except Exception:
                    raise Exception("invalid transaction -- sender tried using money that doesn't belong to them")
        curr = curr.prev.pointer
    return True

# %% [markdown]
# ## Testing using coin-based transactions

# %%
# TEST CASE
key_bob = SigningKey.generate()
key_alice = SigningKey.generate()
pubkey_bob = key_bob.verify_key
pubkey_alice = key_alice.verify_key

# Bob's going to mine some coins
i1 = Input('COINBASE', 0, pubkey_bob)
i1_signed = SignedInput(i1, key_bob.sign(bytes_value(i1)))
o1 = Output(hash_value(pubkey_bob), 10.0)
tx1 = Transaction([i1_signed], [o1])

# And pay some to Alice
i2 = Input(hash_value(tx1), 0, pubkey_bob)
i2_signed = SignedInput(i2, key_bob.sign(bytes_value(i2)))
o2 = Output(hash_value(pubkey_bob), 9.0)
o3 = Output(hash_value(pubkey_alice), 1.0)
tx2 = Transaction([i2_signed], [o2, o3])

# Mine the block
b1, b1_hash = mine_for_block([tx2, tx1], hash_value(pubkey_bob), None, stake=[])

# Alice pays some money back to Bob
i3 = Input(hash_value(tx2), 1, pubkey_alice)
i3_signed = SignedInput(i3, key_alice.sign(bytes_value(i3)))
o4 = Output(hash_value(pubkey_alice), 0.5)
o5 = Output(hash_value(pubkey_bob), 0.5)
tx3 = Transaction([i3_signed], [o4, o5])
b2, b2_hash = mine_for_block([tx3], hash_value(pubkey_bob), b1, stake=[o1, o2])

# Now let the outputs sit for a while so the coin-age can accumulate
filler_input = Input('COINBASE', 0, pubkey_bob)
filler_tx = Transaction([SignedInput(filler_i, key_bob.sign(bytes_value(filler_i)))], [Output(hash_value(pubkey_bob), 0.0)])
prev = b2
for _ in range(10):
    prev, prev_hash = mine_for_block([filler_tx], hash_value(pubkey_bob), prev, stake = [])
    print("difficulty level: ", prev.difficulty)

# Now try mining with aged coins
bf, bf_hash = mine_for_block([filler_tx], hash_value(pubkey_bob), prev, stake=[o4, o5])
print("difficulty level: ", bf.difficulty)

# Now validate the blockchain
if check_blockchain(bf, bf_hash):
    print("valid blockchain!")
# Out:
# Found a block! Nonce:  10886
# Found a block! Nonce:  4941
# Found a block! Nonce:  17638
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  18323
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  36923
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  38600
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  2207
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  1935
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  25298
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  5378
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  23489
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  10016
# difficulty level:  11579208923731620097252891909051370308410783478121767587393979691411963904
# Found a block! Nonce:  2466
# difficulty level:  12852921905342099390750759373249452804009645164037618799663631627513233408
# valid blockchain
